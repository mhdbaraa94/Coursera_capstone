# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np 
import random
from IPython.display import Image
from IPython.core.display import HTML
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\anaconda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.1.23  |                0         158 KB
#     certifi-2019.3.9           |           py37_0         155 KB
#     openssl-1.1.1b             |       he774522_1         5.1 MB
#     ------------------------------------------------------------
#                                            Total:         5.4 MB
#
# The following packages will be UPDATED:
#
#   anaconda                                    custom-py37_1 --> 2019.03-py37_0
#   ca-certificates    conda-forge::ca-certificates-2018.4.1~ --> pkgs/main::ca-certificates-2019.1.23-0
#
# The following packages will be DOWNGRADED:
#
#   certifi                                  2019.9.11-py37_0 --> 2019.3.9-py37_0
#   openssl                                 1.1.1c-he774522_1 --> 1.1.1b-he774522_1
#
#
#
# Downloading and Extracting Packages
#
# openssl-1.1.1b       | 5.1 MB    |            |   0%
# openssl-1.1.1b       | 5.1 MB    |            |   0%
# openssl-1.1.1b       | 5.1 MB    |            |   1%
# openssl-1.1.1b       | 5.1 MB    |            |   1%
# openssl-1.1.1b       | 5.1 MB    | 1          |   1%
# openssl-1.1.1b       | 5.1 MB    | 1          |   2%
# openssl-1.1.1b       | 5.1 MB    | 1          |   2%
# openssl-1.1.1b       | 5.1 MB    | 2          |   2%
# openssl-1.1.1b       | 5.1 MB    | 2          |   2%
# openssl-1.1.1b       | 5.1 MB    | 2          |   3%
# openssl-1.1.1b       | 5.1 MB    | 3          |   3%
# openssl-1.1.1b       | 5.1 MB    | 4          |   4%
# openssl-1.1.1b       | 5.1 MB    | 4          |   5%
# openssl-1.1.1b       | 5.1 MB    | 4          |   5%
# openssl-1.1.1b       | 5.1 MB    | 5          |   5%
# openssl-1.1.1b       | 5.1 MB    | 5          |   6%
# openssl-1.1.1b       | 5.1 MB    | 5          |   6%
# openssl-1.1.1b       | 5.1 MB    | 6          |   6%
# openssl-1.1.1b       | 5.1 MB    | 6          |   6%
# openssl-1.1.1b       | 5.1 MB    | 6          |   7%
# openssl-1.1.1b       | 5.1 MB    | 7          |   7%
# openssl-1.1.1b       | 5.1 MB    | 7          |   7%
# openssl-1.1.1b       | 5.1 MB    | 7          |   8%
# openssl-1.1.1b       | 5.1 MB    | 8          |   8%
# openssl-1.1.1b       | 5.1 MB    | 8          |   9%
# openssl-1.1.1b       | 5.1 MB    | 8          |   9%
# openssl-1.1.1b       | 5.1 MB    | 9          |   9%
# openssl-1.1.1b       | 5.1 MB    | 9          |  10%
# openssl-1.1.1b       | 5.1 MB    | 9          |  10%
# openssl-1.1.1b       | 5.1 MB    | #          |  10%
# openssl-1.1.1b       | 5.1 MB    | #          |  10%
# openssl-1.1.1b       | 5.1 MB    | #          |  11%
# openssl-1.1.1b       | 5.1 MB    | #1         |  11%
# openssl-1.1.1b       | 5.1 MB    | #1         |  11%
# openssl-1.1.1b       | 5.1 MB    | #1         |  12%
# openssl-1.1.1b       | 5.1 MB    | #1         |  12%
# openssl-1.1.1b       | 5.1 MB    | #2         |  13%
# openssl-1.1.1b       | 5.1 MB    | #2         |  13%
# openssl-1.1.1b       | 5.1 MB    | #3         |  13%
# openssl-1.1.1b       | 5.1 MB    | #3         |  14%
# openssl-1.1.1b       | 5.1 MB    | #3         |  14%
# openssl-1.1.1b       | 5.1 MB    | #4         |  14%
# openssl-1.1.1b       | 5.1 MB    | #4         |  14%
# openssl-1.1.1b       | 5.1 MB    | #4         |  15%
# openssl-1.1.1b       | 5.1 MB    | #5         |  15%
# openssl-1.1.1b       | 5.1 MB    | #5         |  15%
# openssl-1.1.1b       | 5.1 MB    | #5         |  16%
# openssl-1.1.1b       | 5.1 MB    | #6         |  17%
# openssl-1.1.1b       | 5.1 MB    | #6         |  17%
# openssl-1.1.1b       | 5.1 MB    | #7         |  17%
# openssl-1.1.1b       | 5.1 MB    | #7         |  17%
# openssl-1.1.1b       | 5.1 MB    | #7         |  18%
# openssl-1.1.1b       | 5.1 MB    | #8         |  18%
# openssl-1.1.1b       | 5.1 MB    | #8         |  18%
# openssl-1.1.1b       | 5.1 MB    | #8         |  19%
# openssl-1.1.1b       | 5.1 MB    | #9         |  19%
# openssl-1.1.1b       | 5.1 MB    | #9         |  19%
# openssl-1.1.1b       | 5.1 MB    | #9         |  20%
# openssl-1.1.1b       | 5.1 MB    | #9         |  20%
# openssl-1.1.1b       | 5.1 MB    | ##         |  20%
# openssl-1.1.1b       | 5.1 MB    | ##         |  21%
# openssl-1.1.1b       | 5.1 MB    | ##         |  21%
# openssl-1.1.1b       | 5.1 MB    | ##1        |  21%
# openssl-1.1.1b       | 5.1 MB    | ##1        |  21%
# openssl-1.1.1b       | 5.1 MB    | ##1        |  22%
# openssl-1.1.1b       | 5.1 MB    | ##2        |  22%
# openssl-1.1.1b       | 5.1 MB    | ##2        |  22%
# openssl-1.1.1b       | 5.1 MB    | ##2        |  23%
# openssl-1.1.1b       | 5.1 MB    | ##3        |  23%
# openssl-1.1.1b       | 5.1 MB    | ##3        |  23%
# openssl-1.1.1b       | 5.1 MB    | ##3        |  24%
# openssl-1.1.1b       | 5.1 MB    | ##3        |  24%
# openssl-1.1.1b       | 5.1 MB    | ##4        |  24%
# openssl-1.1.1b       | 5.1 MB    | ##4        |  25%
# openssl-1.1.1b       | 5.1 MB    | ##4        |  25%
# openssl-1.1.1b       | 5.1 MB    | ##5        |  25%
# openssl-1.1.1b       | 5.1 MB    | ##5        |  25%
# openssl-1.1.1b       | 5.1 MB    | ##5        |  26%
# openssl-1.1.1b       | 5.1 MB    | ##6        |  26%
# openssl-1.1.1b       | 5.1 MB    | ##6        |  26%
# openssl-1.1.1b       | 5.1 MB    | ##6        |  27%
# openssl-1.1.1b       | 5.1 MB    | ##7        |  27%
# openssl-1.1.1b       | 5.1 MB    | ##7        |  28%
# openssl-1.1.1b       | 5.1 MB    | ##8        |  28%
# openssl-1.1.1b       | 5.1 MB    | ##8        |  29%
# openssl-1.1.1b       | 5.1 MB    | ##8        |  29%
# openssl-1.1.1b       | 5.1 MB    | ##9        |  29%
# openssl-1.1.1b       | 5.1 MB    | ##9        |  29%
# openssl-1.1.1b       | 5.1 MB    | ##9        |  30%
# openssl-1.1.1b       | 5.1 MB    | ###        |  30%
# openssl-1.1.1b       | 5.1 MB    | ###        |  30%
# openssl-1.1.1b       | 5.1 MB    | ###        |  31%
# openssl-1.1.1b       | 5.1 MB    | ###1       |  32%
# openssl-1.1.1b       | 5.1 MB    | ###2       |  32%
# openssl-1.1.1b       | 5.1 MB    | ###2       |  33%
# openssl-1.1.1b       | 5.1 MB    | ###2       |  33%
# openssl-1.1.1b       | 5.1 MB    | ###3       |  33%
# openssl-1.1.1b       | 5.1 MB    | ###3       |  33%
# openssl-1.1.1b       | 5.1 MB    | ###3       |  34%
# openssl-1.1.1b       | 5.1 MB    | ###4       |  34%
# openssl-1.1.1b       | 5.1 MB    | ###4       |  34%
# openssl-1.1.1b       | 5.1 MB    | ###4       |  35%
# openssl-1.1.1b       | 5.1 MB    | ###4       |  35%
# openssl-1.1.1b       | 5.1 MB    | ###5       |  35%
# openssl-1.1.1b       | 5.1 MB    | ###5       |  36%
# openssl-1.1.1b       | 5.1 MB    | ###5       |  36%
# openssl-1.1.1b       | 5.1 MB    | ###6       |  36%
# openssl-1.1.1b       | 5.1 MB    | ###6       |  37%
# openssl-1.1.1b       | 5.1 MB    | ###6       |  37%
# openssl-1.1.1b       | 5.1 MB    | ###7       |  37%
# openssl-1.1.1b       | 5.1 MB    | ###7       |  37%
# openssl-1.1.1b       | 5.1 MB    | ###7       |  38%
# openssl-1.1.1b       | 5.1 MB    | ###8       |  38%
# openssl-1.1.1b       | 5.1 MB    | ###8       |  38%
# openssl-1.1.1b       | 5.1 MB    | ###8       |  39%
# openssl-1.1.1b       | 5.1 MB    | ###8       |  39%
# openssl-1.1.1b       | 5.1 MB    | ###9       |  39%
# openssl-1.1.1b       | 5.1 MB    | ###9       |  40%
# openssl-1.1.1b       | 5.1 MB    | ####       |  40%
# openssl-1.1.1b       | 5.1 MB    | ####       |  41%
# openssl-1.1.1b       | 5.1 MB    | ####       |  41%
# openssl-1.1.1b       | 5.1 MB    | ####1      |  41%
# openssl-1.1.1b       | 5.1 MB    | ####1      |  42%
# openssl-1.1.1b       | 5.1 MB    | ####2      |  42%
# openssl-1.1.1b       | 5.1 MB    | ####2      |  42%
# openssl-1.1.1b       | 5.1 MB    | ####2      |  43%
# openssl-1.1.1b       | 5.1 MB    | ####2      |  43%
# openssl-1.1.1b       | 5.1 MB    | ####3      |  43%
# openssl-1.1.1b       | 5.1 MB    | ####3      |  44%
# openssl-1.1.1b       | 5.1 MB    | ####3      |  44%
# openssl-1.1.1b       | 5.1 MB    | ####4      |  44%
# openssl-1.1.1b       | 5.1 MB    | ####4      |  45%
# openssl-1.1.1b       | 5.1 MB    | ####4      |  45%
# openssl-1.1.1b       | 5.1 MB    | ####5      |  45%
# openssl-1.1.1b       | 5.1 MB    | ####5      |  45%
# openssl-1.1.1b       | 5.1 MB    | ####5      |  46%
# openssl-1.1.1b       | 5.1 MB    | ####6      |  46%
# openssl-1.1.1b       | 5.1 MB    | ####6      |  47%
# openssl-1.1.1b       | 5.1 MB    | ####6      |  47%
# openssl-1.1.1b       | 5.1 MB    | ####7      |  47%
# openssl-1.1.1b       | 5.1 MB    | ####7      |  48%
# openssl-1.1.1b       | 5.1 MB    | ####7      |  48%
# openssl-1.1.1b       | 5.1 MB    | ####8      |  48%
# openssl-1.1.1b       | 5.1 MB    | ####8      |  48%
# openssl-1.1.1b       | 5.1 MB    | ####8      |  49%
# openssl-1.1.1b       | 5.1 MB    | ####9      |  49%
# openssl-1.1.1b       | 5.1 MB    | ####9      |  49%
# openssl-1.1.1b       | 5.1 MB    | ####9      |  50%
# openssl-1.1.1b       | 5.1 MB    | #####      |  50%
# openssl-1.1.1b       | 5.1 MB    | #####      |  50%
# openssl-1.1.1b       | 5.1 MB    | #####      |  51%
# openssl-1.1.1b       | 5.1 MB    | #####      |  51%
# openssl-1.1.1b       | 5.1 MB    | #####1     |  51%
# openssl-1.1.1b       | 5.1 MB    | #####1     |  52%
# openssl-1.1.1b       | 5.1 MB    | #####1     |  52%
# openssl-1.1.1b       | 5.1 MB    | #####2     |  52%
# openssl-1.1.1b       | 5.1 MB    | #####2     |  52%
# openssl-1.1.1b       | 5.1 MB    | #####2     |  53%
# openssl-1.1.1b       | 5.1 MB    | #####3     |  53%
# openssl-1.1.1b       | 5.1 MB    | #####3     |  53%
# openssl-1.1.1b       | 5.1 MB    | #####3     |  54%
# openssl-1.1.1b       | 5.1 MB    | #####4     |  54%
# openssl-1.1.1b       | 5.1 MB    | #####4     |  54%
# openssl-1.1.1b       | 5.1 MB    | #####4     |  55%
# openssl-1.1.1b       | 5.1 MB    | #####4     |  55%
# openssl-1.1.1b       | 5.1 MB    | #####5     |  55%
# openssl-1.1.1b       | 5.1 MB    | #####5     |  56%
# openssl-1.1.1b       | 5.1 MB    | #####5     |  56%
# openssl-1.1.1b       | 5.1 MB    | #####6     |  56%
# openssl-1.1.1b       | 5.1 MB    | #####6     |  56%
# openssl-1.1.1b       | 5.1 MB    | #####6     |  57%
# openssl-1.1.1b       | 5.1 MB    | #####7     |  57%
# openssl-1.1.1b       | 5.1 MB    | #####7     |  57%
# openssl-1.1.1b       | 5.1 MB    | #####7     |  58%
# openssl-1.1.1b       | 5.1 MB    | #####8     |  58%
# openssl-1.1.1b       | 5.1 MB    | #####8     |  58%
# openssl-1.1.1b       | 5.1 MB    | #####8     |  59%
# openssl-1.1.1b       | 5.1 MB    | #####8     |  59%
# openssl-1.1.1b       | 5.1 MB    | #####9     |  59%
# openssl-1.1.1b       | 5.1 MB    | #####9     |  60%
# openssl-1.1.1b       | 5.1 MB    | #####9     |  60%
# openssl-1.1.1b       | 5.1 MB    | ######     |  60%
# openssl-1.1.1b       | 5.1 MB    | ######     |  60%
# openssl-1.1.1b       | 5.1 MB    | ######     |  61%
# openssl-1.1.1b       | 5.1 MB    | ######1    |  61%
# openssl-1.1.1b       | 5.1 MB    | ######1    |  61%
# openssl-1.1.1b       | 5.1 MB    | ######1    |  62%
# openssl-1.1.1b       | 5.1 MB    | ######2    |  62%
# openssl-1.1.1b       | 5.1 MB    | ######2    |  62%
# openssl-1.1.1b       | 5.1 MB    | ######2    |  63%
# openssl-1.1.1b       | 5.1 MB    | ######2    |  63%
# openssl-1.1.1b       | 5.1 MB    | ######3    |  63%
# openssl-1.1.1b       | 5.1 MB    | ######3    |  64%
# openssl-1.1.1b       | 5.1 MB    | ######3    |  64%
# openssl-1.1.1b       | 5.1 MB    | ######4    |  64%
# openssl-1.1.1b       | 5.1 MB    | ######4    |  64%
# openssl-1.1.1b       | 5.1 MB    | ######4    |  65%
# openssl-1.1.1b       | 5.1 MB    | ######5    |  65%
# openssl-1.1.1b       | 5.1 MB    | ######5    |  65%
# openssl-1.1.1b       | 5.1 MB    | ######5    |  66%
# openssl-1.1.1b       | 5.1 MB    | ######5    |  66%
# openssl-1.1.1b       | 5.1 MB    | ######6    |  66%
# openssl-1.1.1b       | 5.1 MB    | ######6    |  67%
# openssl-1.1.1b       | 5.1 MB    | ######6    |  67%
# openssl-1.1.1b       | 5.1 MB    | ######7    |  67%
# openssl-1.1.1b       | 5.1 MB    | ######7    |  68%
# openssl-1.1.1b       | 5.1 MB    | ######7    |  68%
# openssl-1.1.1b       | 5.1 MB    | ######8    |  68%
# openssl-1.1.1b       | 5.1 MB    | ######8    |  68%
# openssl-1.1.1b       | 5.1 MB    | ######8    |  69%
# openssl-1.1.1b       | 5.1 MB    | ######9    |  69%
# openssl-1.1.1b       | 5.1 MB    | ######9    |  69%
# openssl-1.1.1b       | 5.1 MB    | ######9    |  70%
# openssl-1.1.1b       | 5.1 MB    | ######9    |  70%
# openssl-1.1.1b       | 5.1 MB    | #######    |  70%
# openssl-1.1.1b       | 5.1 MB    | #######    |  71%
# openssl-1.1.1b       | 5.1 MB    | #######    |  71%
# openssl-1.1.1b       | 5.1 MB    | #######1   |  71%
# openssl-1.1.1b       | 5.1 MB    | #######1   |  72%
# openssl-1.1.1b       | 5.1 MB    | #######1   |  72%
# openssl-1.1.1b       | 5.1 MB    | #######2   |  72%
# openssl-1.1.1b       | 5.1 MB    | #######2   |  72%
# openssl-1.1.1b       | 5.1 MB    | #######2   |  73%
# openssl-1.1.1b       | 5.1 MB    | #######3   |  73%
# openssl-1.1.1b       | 5.1 MB    | #######3   |  73%
# openssl-1.1.1b       | 5.1 MB    | #######3   |  74%
# openssl-1.1.1b       | 5.1 MB    | #######3   |  74%
# openssl-1.1.1b       | 5.1 MB    | #######4   |  74%
# openssl-1.1.1b       | 5.1 MB    | #######4   |  75%
# openssl-1.1.1b       | 5.1 MB    | #######4   |  75%
# openssl-1.1.1b       | 5.1 MB    | #######5   |  75%
# openssl-1.1.1b       | 5.1 MB    | #######5   |  76%
# openssl-1.1.1b       | 5.1 MB    | #######5   |  76%
# openssl-1.1.1b       | 5.1 MB    | #######6   |  76%
# openssl-1.1.1b       | 5.1 MB    | #######6   |  76%
# openssl-1.1.1b       | 5.1 MB    | #######6   |  77%
# openssl-1.1.1b       | 5.1 MB    | #######7   |  77%
# openssl-1.1.1b       | 5.1 MB    | #######7   |  77%
# openssl-1.1.1b       | 5.1 MB    | #######7   |  78%
# openssl-1.1.1b       | 5.1 MB    | #######7   |  78%
# openssl-1.1.1b       | 5.1 MB    | #######8   |  78%
# openssl-1.1.1b       | 5.1 MB    | #######8   |  79%
# openssl-1.1.1b       | 5.1 MB    | #######8   |  79%
# openssl-1.1.1b       | 5.1 MB    | #######9   |  79%
# openssl-1.1.1b       | 5.1 MB    | #######9   |  79%
# openssl-1.1.1b       | 5.1 MB    | #######9   |  80%
# openssl-1.1.1b       | 5.1 MB    | ########   |  80%
# openssl-1.1.1b       | 5.1 MB    | ########   |  80%
# openssl-1.1.1b       | 5.1 MB    | ########   |  81%
# openssl-1.1.1b       | 5.1 MB    | ########1  |  81%
# openssl-1.1.1b       | 5.1 MB    | ########1  |  81%
# openssl-1.1.1b       | 5.1 MB    | ########1  |  82%
# openssl-1.1.1b       | 5.1 MB    | ########1  |  82%
# openssl-1.1.1b       | 5.1 MB    | ########2  |  82%
# openssl-1.1.1b       | 5.1 MB    | ########2  |  83%
# openssl-1.1.1b       | 5.1 MB    | ########2  |  83%
# openssl-1.1.1b       | 5.1 MB    | ########3  |  83%
# openssl-1.1.1b       | 5.1 MB    | ########3  |  83%
# openssl-1.1.1b       | 5.1 MB    | ########3  |  84%
# openssl-1.1.1b       | 5.1 MB    | ########4  |  84%
# openssl-1.1.1b       | 5.1 MB    | ########4  |  84%
# openssl-1.1.1b       | 5.1 MB    | ########4  |  85%
# openssl-1.1.1b       | 5.1 MB    | ########5  |  85%
# openssl-1.1.1b       | 5.1 MB    | ########5  |  85%
# openssl-1.1.1b       | 5.1 MB    | ########5  |  86%
# openssl-1.1.1b       | 5.1 MB    | ########5  |  86%
# openssl-1.1.1b       | 5.1 MB    | ########6  |  86%
# openssl-1.1.1b       | 5.1 MB    | ########6  |  87%
# openssl-1.1.1b       | 5.1 MB    | ########6  |  87%
# openssl-1.1.1b       | 5.1 MB    | ########7  |  87%
# openssl-1.1.1b       | 5.1 MB    | ########7  |  87%
# openssl-1.1.1b       | 5.1 MB    | ########7  |  88%
# openssl-1.1.1b       | 5.1 MB    | ########8  |  88%
# openssl-1.1.1b       | 5.1 MB    | ########8  |  88%
# openssl-1.1.1b       | 5.1 MB    | ########8  |  89%
# openssl-1.1.1b       | 5.1 MB    | ########9  |  89%
# openssl-1.1.1b       | 5.1 MB    | ########9  |  89%
# openssl-1.1.1b       | 5.1 MB    | ########9  |  90%
# openssl-1.1.1b       | 5.1 MB    | ########9  |  90%
# openssl-1.1.1b       | 5.1 MB    | #########  |  90%
# openssl-1.1.1b       | 5.1 MB    | #########  |  91%
# openssl-1.1.1b       | 5.1 MB    | #########  |  91%
# openssl-1.1.1b       | 5.1 MB    | #########1 |  91%
# openssl-1.1.1b       | 5.1 MB    | #########1 |  91%
# openssl-1.1.1b       | 5.1 MB    | #########1 |  92%
# openssl-1.1.1b       | 5.1 MB    | #########2 |  92%
# openssl-1.1.1b       | 5.1 MB    | #########2 |  92%
# openssl-1.1.1b       | 5.1 MB    | #########2 |  93%
# openssl-1.1.1b       | 5.1 MB    | #########3 |  93%
# openssl-1.1.1b       | 5.1 MB    | #########3 |  93%
# openssl-1.1.1b       | 5.1 MB    | #########3 |  94%
# openssl-1.1.1b       | 5.1 MB    | #########3 |  94%
# openssl-1.1.1b       | 5.1 MB    | #########4 |  94%
# openssl-1.1.1b       | 5.1 MB    | #########4 |  95%
# openssl-1.1.1b       | 5.1 MB    | #########4 |  95%
# openssl-1.1.1b       | 5.1 MB    | #########5 |  95%
# openssl-1.1.1b       | 5.1 MB    | #########5 |  95%
# openssl-1.1.1b       | 5.1 MB    | #########5 |  96%
# openssl-1.1.1b       | 5.1 MB    | #########6 |  96%
# openssl-1.1.1b       | 5.1 MB    | #########6 |  96%
# openssl-1.1.1b       | 5.1 MB    | #########6 |  97%
# openssl-1.1.1b       | 5.1 MB    | #########6 |  97%
# openssl-1.1.1b       | 5.1 MB    | #########7 |  97%
# openssl-1.1.1b       | 5.1 MB    | #########7 |  98%
# openssl-1.1.1b       | 5.1 MB    | #########7 |  98%
# openssl-1.1.1b       | 5.1 MB    | #########8 |  98%
# openssl-1.1.1b       | 5.1 MB    | #########8 |  99%
# openssl-1.1.1b       | 5.1 MB    | #########8 |  99%
# openssl-1.1.1b       | 5.1 MB    | #########9 |  99%
# openssl-1.1.1b       | 5.1 MB    | #########9 | 100%
# openssl-1.1.1b       | 5.1 MB    | ########## | 100%
#
# ca-certificates-2019 | 158 KB    |            |   0%
# ca-certificates-2019 | 158 KB    | #          |  10%
# ca-certificates-2019 | 158 KB    | ##         |  20%
# ca-certificates-2019 | 158 KB    | ###        |  30%
# ca-certificates-2019 | 158 KB    | ####       |  40%
# ca-certificates-2019 | 158 KB    | #####      |  51%
# ca-certificates-2019 | 158 KB    | ######     |  61%
# ca-certificates-2019 | 158 KB    | #######    |  71%
# ca-certificates-2019 | 158 KB    | ########   |  81%
# ca-certificates-2019 | 158 KB    | #########1 |  91%
# ca-certificates-2019 | 158 KB    | ########## | 100%
#
# certifi-2019.3.9     | 155 KB    |            |   0%
# certifi-2019.3.9     | 155 KB    | #          |  10%
# certifi-2019.3.9     | 155 KB    | ##         |  21%
# certifi-2019.3.9     | 155 KB    | ###        |  31%
# certifi-2019.3.9     | 155 KB    | ####1      |  41%
# certifi-2019.3.9     | 155 KB    | #####1     |  52%
# certifi-2019.3.9     | 155 KB    | ######1    |  62%
# certifi-2019.3.9     | 155 KB    | #######2   |  72%
# certifi-2019.3.9     | 155 KB    | ########2  |  82%
# certifi-2019.3.9     | 155 KB    | #########2 |  93%
# certifi-2019.3.9     | 155 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Folium installed
# Libraries imported.

# %%
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
table_rows = table.tbody.find_all("tr")

res = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [tr.text for tr in td]
    
    if row != [] and row[1] != "Not assigned":
        if "Not assigned" in row[2]: 
            row[2] = row[1]
        res.append(row)

df = pd.DataFrame(res, columns = ["PostalCode", "Borough", "Neighborhood"])
df.head()
# Out:
#   PostalCode           Borough        Neighborhood
# 0        M3A        North York         Parkwoods\n
# 1        M4A        North York  Victoria Village\n
# 2        M5A  Downtown Toronto      Harbourfront\n
# 3        M5A  Downtown Toronto       Regent Park\n
# 4        M6A        North York  Lawrence Heights\n

# %%
df["Neighborhood"] = df["Neighborhood"].str.replace("\n","")
df = df.groupby(["PostalCode", "Borough"])["Neighborhood"].apply(", ".join).reset_index()
df.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
table_rows = table.tbody.find_all("tr")

res = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [tr.text for tr in td]
    
    if row != [] and row[1] != "Not assigned":
        if "Not assigned" in row[2]: 
            row[2] = row[1]
        res.append(row)

df = pd.DataFrame(res, columns = ["PostalCode", "Borough", "Neighborhood"])
df.head()
# Out:
#   PostalCode           Borough        Neighborhood
# 0        M3A        North York         Parkwoods\n
# 1        M4A        North York  Victoria Village\n
# 2        M5A  Downtown Toronto      Harbourfront\n
# 3        M5A  Downtown Toronto       Regent Park\n
# 4        M6A        North York  Lawrence Heights\n
